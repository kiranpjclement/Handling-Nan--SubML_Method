# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.svm import SVC
from sklearn.svm import SVR
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("titanic_train.csv")
df2=pd.read_csv("titanic_test.csv")  #test data

# %%
177/891
# Out:
# 0.19865319865319866

# %% [markdown]
# ## Filling Nan Age Using the Model to predict Age

# %%
filt=df['Age'].isnull()
Null_Age_df=df.loc[filt]
Null_Age_df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
X_Null_Age_df=Null_Age_df[['Pclass','Sex','SibSp','Fare','Embarked','Survived']]

# %%
temp_x1=pd.get_dummies(X_Null_Age_df['Embarked'],drop_first=True)
X_Null_Age_df=pd.concat([X_Null_Age_df,temp_x1],axis=1)
X_Null_Age_df.drop(columns='Embarked',inplace=True)

# %%
temp_x2=pd.get_dummies(X_Null_Age_df['Sex'],drop_first=True)
X_Null_Age_df=pd.concat([X_Null_Age_df,temp_x2],axis=1)
X_Null_Age_df.drop(columns='Sex',inplace=True)

# %%
temp_x3=pd.get_dummies(X_Null_Age_df['Survived'],drop_first=True)
X_Null_Age_df=pd.concat([X_Null_Age_df,temp_x3],axis=1)
X_Null_Age_df.drop(columns='Survived',inplace=True)

# %%
X_Null_Age_df
# Out:
#      Pclass  SibSp     Fare  Q  S  male  1
# 5         3      0   8.4583  1  0     1  0
# 17        2      0  13.0000  0  1     1  1
# 19        3      0   7.2250  0  0     0  1
# 26        3      0   7.2250  0  0     1  0
# 28        3      0   7.8792  1  0     0  1
# ..      ...    ...      ... .. ..   ... ..
# 859       3      0   7.2292  0  0     1  0
# 863       3      8  69.5500  0  1     0  0
# 868       3      0   9.5000  0  1     1  0
# 878       3      0   7.8958  0  1     1  0
# 888       3      1  23.4500  0  1     0  0
#
# [177 rows x 7 columns]

# %% [markdown]
# #### Calling the Joblib file to reuse the model

# %%
from joblib import dump, load
mod3 = load('Age_prediction.joblib')  #load the data in another notebook
pred=mod3.predict(X_Null_Age_df)

# %%
Null_Age_df.loc[:,'Age']
# Out:
# 5      -52.621513
# 17     -74.613182
# 19     -56.397183
# 26     -49.590265
# 28     -55.821657
#           ...
# 859    -49.616424
# 863   -616.621366
# 868    -62.793163
# 878    -52.801818
# 888   -172.675470
# Name: Age, Length: 177, dtype: float64

# %% [markdown]
# ##### Fill the Missing Age with Predicted Age

# %%
filt=df['Age'].isnull()
df.loc[filt,'Age']=pred

# %% [raw]
# The Above method can be used to fill the Missing Feature in any Data Set.
# But the model efficiency depends on the accuracy of the model created to predict the missing feature
